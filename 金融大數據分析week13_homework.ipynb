# %%
pip install  numpy pandas
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import numpy as np
import pandas as pd
import random

# 配置參數
NUM_STOCKS = 10  # 總股票數量
POPULATION_SIZE = 50  # 初始族群大小
GENERATIONS = 100  # 最大迭代次數
MUTATION_RATE = 0.1  # 突變率

# 模擬股票回報率和風險
def simulate_stock_data(num_stocks):
    np.random.seed(42)
    returns = np.random.uniform(0.05, 0.2, num_stocks)  # 模擬每支股票的回報率
    risks = np.random.uniform(0.1, 0.5, num_stocks)  # 模擬每支股票的風險
    return pd.DataFrame({"Stock": [f"Stock_{i+1}" for i in range(num_stocks)], "Return": returns, "Risk": risks})

# 定義適應函數
# 目標是最大化回報率並最小化風險
def fitness_function(portfolio, stock_data):
    total_return = np.sum(portfolio * stock_data["Return"].values)
    total_risk = np.sqrt(np.sum((portfolio * stock_data["Risk"].values) ** 2))
    return total_return - total_risk  # 簡單的回報與風險權衡模型

# 初始化族群
def initialize_population(pop_size, num_stocks):
    return np.random.randint(2, size=(pop_size, num_stocks))


# 選擇
# 根據適應值選擇最優染色體
def select_parents(population, fitness_scores):
    # 確保適應值為正數
    min_fitness = np.min(fitness_scores)
    if min_fitness < 0:
        fitness_scores += abs(min_fitness) + 1e-6  # 平移所有適應值使其為正數

    # 防止分母為零
    total_fitness = np.sum(fitness_scores)
    if total_fitness == 0:
        probabilities = np.ones_like(fitness_scores) / len(fitness_scores)  # 平均分佈
    else:
        probabilities = fitness_scores / total_fitness

    # 選擇父母染色體
    parents_indices = np.random.choice(len(population), size=2, replace=False, p=probabilities)
    return population[parents_indices]


# 交配（單點交叉）
def crossover(parent1, parent2):
    crossover_point = np.random.randint(1, len(parent1))
    child1 = np.concatenate((parent1[:crossover_point], parent2[crossover_point:]))
    child2 = np.concatenate((parent2[:crossover_point], parent1[crossover_point:]))
    return child1, child2

# 突變
def mutate(chromosome, mutation_rate):
    for i in range(len(chromosome)):
        if random.random() < mutation_rate:
            chromosome[i] = 1 - chromosome[i]  # 基因翻轉
    return chromosome

# 運行基因演算法
def genetic_algorithm(stock_data):
    num_stocks = len(stock_data)
    population = initialize_population(POPULATION_SIZE, num_stocks)

    for generation in range(GENERATIONS):
        fitness_scores = np.array([fitness_function(ind, stock_data) for ind in population])

        new_population = []
        while len(new_population) < POPULATION_SIZE:
            parents = select_parents(population, fitness_scores)
            child1, child2 = crossover(parents[0], parents[1])
            new_population.append(mutate(child1, MUTATION_RATE))
            new_population.append(mutate(child2, MUTATION_RATE))

        population = np.array(new_population[:POPULATION_SIZE])

        # 輸出每代最佳適應值
        best_fitness = np.max(fitness_scores)
        print(f"Generation {generation+1}: Best Fitness = {best_fitness:.4f}")

    # 返回最佳染色體及其適應值
    best_index = np.argmax(fitness_scores)
    best_chromosome = population[best_index]
    best_return = np.sum(best_chromosome * stock_data["Return"].values)
    best_risk = np.sqrt(np.sum((best_chromosome * stock_data["Risk"].values) ** 2))
    return best_chromosome, best_return, best_risk

# 主程式執行邏輯
def main():
    stock_data = simulate_stock_data(NUM_STOCKS)
    print("模擬股票數據:")
    print(stock_data)

    print("\n運行基因演算法...")
    best_portfolio, best_return, best_risk = genetic_algorithm(stock_data)

    print("\n最佳投資組合:")
    for i, selected in enumerate(best_portfolio):
        if selected:
            print(f"{stock_data['Stock'][i]}: Included")
    print(f"\n投資組合回報率: {best_return:.4f}")
    print(f"投資組合風險: {best_risk:.4f}")

if __name__ == "__main__":
    main()
# Out:
# 模擬股票數據:
#       Stock    Return      Risk
# 0   Stock_1  0.106181  0.108234
# 1   Stock_2  0.192607  0.487964
# 2   Stock_3  0.159799  0.432977
# 3   Stock_4  0.139799  0.184936
# 4   Stock_5  0.073403  0.172730
# 5   Stock_6  0.073399  0.173362
# 6   Stock_7  0.058713  0.221697
# 7   Stock_8  0.179926  0.309903
# 8   Stock_9  0.140167  0.272778
# 9  Stock_10  0.156211  0.216492
#
# 運行基因演算法...
# Generation 1: Best Fitness = 0.4472
# Generation 2: Best Fitness = 0.4112
# Generation 3: Best Fitness = 0.3673
# Generation 4: Best Fitness = 0.4969
# Generation 5: Best Fitness = 0.4511
# Generation 6: Best Fitness = 0.5514
# Generation 7: Best Fitness = 0.5489
# Generation 8: Best Fitness = 0.4477
# Generation 9: Best Fitness = 0.4977
# Generation 10: Best Fitness = 0.4835
# Generation 11: Best Fitness = 0.3972
# Generation 12: Best Fitness = 0.4597
# Generation 13: Best Fitness = 0.4034
# Generation 14: Best Fitness = 0.5267
# Generation 15: Best Fitness = 0.5260
# Generation 16: Best Fitness = 0.3976
# Generation 17: Best Fitness = 0.4515
# Generation 18: Best Fitness = 0.4115
# Generation 19: Best Fitness = 0.4693
# Generation 20: Best Fitness = 0.4485
# Generation 21: Best Fitness = 0.3562
# Generation 22: Best Fitness = 0.4989
# Generation 23: Best Fitness = 0.4632
# Generation 24: Best Fitness = 0.4786
# Generation 25: Best Fitness = 0.4304
# Generation 26: Best Fitness = 0.4203
# Generation 27: Best Fitness = 0.5258
# Generation 28: Best Fitness = 0.5240
# Generation 29: Best Fitness = 0.4045
# Generation 30: Best Fitness = 0.4089
# Generation 31: Best Fitness = 0.4281
# Generation 32: Best Fitness = 0.3950
# Generation 33: Best Fitness = 0.3803
# Generation 34: Best Fitness = 0.4797
# Generation 35: Best Fitness = 0.3593
# Generation 36: Best Fitness = 0.4211
# Generation 37: Best Fitness = 0.5157
# Generation 38: Best Fitness = 0.4201
# Generation 39: Best Fitness = 0.3693
# Generation 40: Best Fitness = 0.4231
# Generation 41: Best Fitness = 0.4446
# Generation 42: Best Fitness = 0.5295
# Generation 43: Best Fitness = 0.4642
# Generation 44: Best Fitness = 0.3497
# Generation 45: Best Fitness = 0.4102
# Generation 46: Best Fitness = 0.5150
# Generation 47: Best Fitness = 0.5480
# Generation 48: Best Fitness = 0.5253
# Generation 49: Best Fitness = 0.4960
# Generation 50: Best Fitness = 0.3872
# Generation 51: Best Fitness = 0.5311
# Generation 52: Best Fitness = 0.4130
# Generation 53: Best Fitness = 0.5138
# Generation 54: Best Fitness = 0.4665
# Generation 55: Best Fitness = 0.4855
# Generation 56: Best Fitness = 0.4585
# Generation 57: Best Fitness = 0.3925
# Generation 58: Best Fitness = 0.4560
# Generation 59: Best Fitness = 0.5636
# Generation 60: Best Fitness = 0.4135
# Generation 61: Best Fitness = 0.3843
# Generation 62: Best Fitness = 0.3745
# Generation 63: Best Fitness = 0.3974
# Generation 64: Best Fitness = 0.5575
# Generation 65: Best Fitness = 0.4912
# Generation 66: Best Fitness = 0.4244
# Generation 67: Best Fitness = 0.3806
# Generation 68: Best Fitness = 0.4449
# Generation 69: Best Fitness = 0.3566
# Generation 70: Best Fitness = 0.4865
# Generation 71: Best Fitness = 0.4342
# Generation 72: Best Fitness = 0.4855
# Generation 73: Best Fitness = 0.4275
# Generation 74: Best Fitness = 0.3870
# Generation 75: Best Fitness = 0.4300
# Generation 76: Best Fitness = 0.5150
# Generation 77: Best Fitness = 0.4322
# Generation 78: Best Fitness = 0.5764
# Generation 79: Best Fitness = 0.4253
# Generation 80: Best Fitness = 0.4389
# Generation 81: Best Fitness = 0.3984
# Generation 82: Best Fitness = 0.5908
# Generation 83: Best Fitness = 0.4672
# Generation 84: Best Fitness = 0.3861
# Generation 85: Best Fitness = 0.3696
# Generation 86: Best Fitness = 0.3674
# Generation 87: Best Fitness = 0.3750
# Generation 88: Best Fitness = 0.3391
# Generation 89: Best Fitness = 0.4026
# Generation 90: Best Fitness = 0.4782
# Generation 91: Best Fitness = 0.3376
# Generation 92: Best Fitness = 0.4508
# Generation 93: Best Fitness = 0.4567
# Generation 94: Best Fitness = 0.3951
# Generation 95: Best Fitness = 0.4933
# Generation 96: Best Fitness = 0.4242
# Generation 97: Best Fitness = 0.5385
# Generation 98: Best Fitness = 0.4191
# Generation 99: Best Fitness = 0.4302
# Generation 100: Best Fitness = 0.3870
#
# 最佳投資組合:
# Stock_2: Included
# Stock_3: Included
# Stock_4: Included
# Stock_5: Included
# Stock_8: Included
# Stock_9: Included
#
# 投資組合回報率: 0.8857
# 投資組合風險: 0.8124
